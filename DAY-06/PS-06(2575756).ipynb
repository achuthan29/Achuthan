# %% [markdown]
# # 6.Online Shopping Cart
#
# Scenario: You are tasked with designing a class hierarchy for an online shopping cart system. The system should handle products, shopping carts, and orders. Consider various OOP principles while designing this system.
#
# 1. Create a class hierarchy that includes classes for products (e.g., Product), shopping carts (e.g., ShoppingCart), and orders (e.g., Order). Define attributes and methods for each class.
#
# 2 Implement encapsulation by making relevant attributes private and providing getter and setter methods where necessary.
#
# 3. Use inheritance to represent different types of products (eg, electronics, clothing) as subclasses of the Product class. Ensure that each product type can have specific attributes and methods.
#
# 4. Demonstrate polymorphism by allowing various product types to be added to a shopping cart and calculate the total cost of items in the cart.
#
# 5. Implement a method for placing an order, which transfers items from the shopping cart to an order.
#
# Consider scenarios like out-of-stock products, discounts, and shipping costs in your design.

# %%
class Product:
    def __init__(self, product_id, name, price, description, in_stock):
        self.__product_id = product_id  
        self.__name = name 
        self.__price = price  
        self.__description = description  
        self.__in_stock = in_stock  
    def get_product_id(self):
        return self.__product_id
    def get_name(self):
        return self.__name
    def get_price(self):
        return self.__price
    def get_description(self):
        return self.__description
    def is_in_stock(self):
        return self.__in_stock
    def set_name(self, name):
        self.__name = name
    def set_price(self, price):
        self.__price = price
    def set_description(self, description):
        self.__description = description
    def set_in_stock(self, in_stock):
        self.__in_stock = in_stock
class Electronics(Product):
    def __init__(self, product_id, name, price, description, in_stock, brand):
        super().__init__(product_id, name, price, description, in_stock)
        self.__brand = brand  
    def get_brand(self):
        return self.__brand
class Clothing(Product):
    def __init__(self, product_id, name, price, description, in_stock, size):
        super().__init__(product_id, name, price, description, in_stock)
        self.__size = size 
    def get_size(self):
        return self.__size
class ShoppingCart:
    def __init__(self):
        self.__items = []  
    def add_item(self, item):
        self.__items.append(item)
    def remove_item(self, item):
        if item in self.__items:
            self.__items.remove(item)
    def calculate_total_cost(self):
        total_cost = 0
        for item in self.__items:
            total_cost += item.get_price()
        return total_cost

class Order:
    def __init__(self, order_id, cart, shipping_address):
        self.__order_id = order_id  
        self.__cart = cart  
        self.__shipping_address = shipping_address  
    def place_order(self):
        for item in self.__cart.get_items():
            if not item.is_in_stock():
                return "One or more items are out of stock. Order cannot be placed."
        total_cost = self.__cart.calculate_total_cost()
        shipping_cost = 10 
        if total_cost > 100:
            total_cost *= 0.9
        final_cost = total_cost + shipping_cost
        return f"Order placed successfully. Total cost: ${final_cost}"

electronics_item = Electronics("E001", "Laptop", 800, "High-performance laptop", True, "Dell")
clothing_item = Clothing("C001", "T-Shirt", 20, "Cotton T-shirt", True, "Large")

cart = ShoppingCart()
cart.add_item(electronics_item)
cart.add_item(clothing_item)
order = Order("O001",cart, "123 Main St, City")
result = order.place_order()
print(result)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[21], line 75
#      73 cart.add_item(clothing_item)
#      74 order = Order("O001",cart, "123 Main St, City")
# ---> 75 result = order.place_order()
#      76 print(result)
#
# Cell In[21], line 58, in Order.place_order(self)
#      57 def place_order(self):
# ---> 58     for item in self.__cart.get_items():
#      59         if not item.is_in_stock():
#      60             return "One or more items are out of stock. Order cannot be placed."
#
# AttributeError: 'ShoppingCart' object has no attribute 'get_items'
